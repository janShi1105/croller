# %%
import requests
from janome.tokenizer import Tokenizer
from bs4 import BeautifulSoup
from wordcloud import WordCloud

url = 'http://www.aozora.gr.jp/cards/000879/files/42_15228.html'
r = requests.get(url, timeout=10)

soup = BeautifulSoup(r.content, 'lxml')

text_elm = soup.find('div', attrs={'class': 'main_text'})

[e.extract() for e in text_elm.select('rt')]

text = text_elm.text

stop_word_url = 'http://svn.sourceforge.jp/svnroot/slothlib/CSharp/Version1/SlothLib/Filter/StopWord/word/Japanese.txt'
r_stopword = requests.get(stop_word_url, timeout=10)
stop_words = r_stopword.text.split()

t = Tokenizer()
words = []
for token in t.tokenize(text):
    if token.part_of_speech.split(',')[0] == '名詞' and token.surface not in stop_words:
            words.append(token.surface)
            
font_path = '/System/Library/Fonts/ヒラギノ角ゴシック W3.ttc'
wordcloud = WordCloud(background_color='white', font_path=font_path, regexp=r"\w+").generate(" ".join(words))

import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 31>()
#      28 wordcloud = WordCloud(background_color='white', font_path=font_path, regexp=r"\w+").generate(" ".join(words))
#      30 import matplotlib.pyplot as plt
# ---> 31 plt.imshow(wordcloud, interpolatiom='bilinear')
#      32 plt.axis("off")
#      33 plt.show()
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/matplotlib/pyplot.py:2640, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2634 @_copy_docstring_and_deprecators(Axes.imshow)
#    2635 def imshow(
#    2636         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    2637         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    2638         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2639         resample=None, url=None, data=None, **kwargs):
# -> 2640     __ret = gca().imshow(
#    2641         X, cmap=cmap, norm=norm, aspect=aspect,
#    2642         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2643         vmax=vmax, origin=origin, extent=extent,
#    2644         interpolation_stage=interpolation_stage,
#    2645         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2646         url=url, **({"data": data} if data is not None else {}),
#    2647         **kwargs)
#    2648     sci(__ret)
#    2649     return __ret
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5482, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5480     aspect = rcParams['image.aspect']
#    5481 self.set_aspect(aspect)
# -> 5482 im = mimage.AxesImage(self, cmap, norm, interpolation,
#    5483                       origin, extent, filternorm=filternorm,
#    5484                       filterrad=filterrad, resample=resample,
#    5485                       interpolation_stage=interpolation_stage,
#    5486                       **kwargs)
#    5488 im.set_data(X)
#    5489 im.set_alpha(alpha)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/matplotlib/image.py:929, in AxesImage.__init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     913 def __init__(self, ax,
#     914              cmap=None,
#     915              norm=None,
#    (...)
#     924              **kwargs
#     925              ):
#     927     self._extent = extent
# --> 929     super().__init__(
#     930         ax,
#     931         cmap=cmap,
#     932         norm=norm,
#     933         interpolation=interpolation,
#     934         origin=origin,
#     935         filternorm=filternorm,
#     936         filterrad=filterrad,
#     937         resample=resample,
#     938         interpolation_stage=interpolation_stage,
#     939         **kwargs
#     940     )
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/matplotlib/image.py:260, in _ImageBase.__init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     256 self.axes = ax
#     258 self._imcache = None
# --> 260 self.update(kwargs)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/matplotlib/artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'AxesImage' object has no property 'interpolatiom'
